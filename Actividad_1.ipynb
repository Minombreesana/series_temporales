# %% [markdown]
# 1. Generar serie de tiempo y graficarla

# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd

# %%
mean = 0
std = 1 
num_samples = 500
X = numpy.random.normal(mean, std, size=num_samples)

plt.plot(X)
plt.show()

# %%
df = pd.DataFrame(X)
df.describe()
# Out:
#                 0
# count  500.000000
# mean    -0.085408
# std      1.013928
# min     -3.143837
# 25%     -0.818893
# 50%     -0.084658
# 75%      0.682091
# max      2.675620

# %%
plt.hist(X, bins = 30)
plt.show()

# %% [markdown]
# 2. graficar serie de tiempo con dataset

# %%
df = pd.read_csv('../contenido/TimeSeries/Datasets/airmiles.csv')

# %%
df.head(70)
# Out:
#     Unnamed: 0  airmiles
# 0            1  30983174
# 1            2  32147663
# 2            3  38342975
# 3            4  35969113
# 4            5  36474391
# ..         ...       ...
# 65          66  46654145
# 66          67  49597273
# 67          68  50169907
# 68          69  27077913
# 69          70  34181554
#
# [70 rows x 2 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0      airmiles
# count   113.00000  1.130000e+02
# mean     57.00000  4.050524e+07
# std      32.76431  5.604899e+06
# min       1.00000  2.707791e+07
# 25%      29.00000  3.638984e+07
# 50%      57.00000  4.023825e+07
# 75%      85.00000  4.406002e+07
# max     113.00000  5.431731e+07

# %%
plt.plot(df['airmiles'])
plt.show()

#Queda graficado sin unidades de tiempo porque no las tiene

# %% [markdown]
# 3. describir tres series distintas

# %%
df_2 = pd.read_csv('../contenido/TimeSeries/Datasets/catfish.csv')
df_2.tail()
# Out:
#            Date  Total
# 319   2012-8-01  14442
# 320   2012-9-01  13422
# 321  2012-10-01  13795
# 322  2012-11-01  13352
# 323  2012-12-01  12716

# %%
df_2.describe()
# Out:
#               Total
# count    324.000000
# mean   19643.984568
# std     5039.324331
# min     8196.000000
# 25%    15764.000000
# 50%    19660.500000
# 75%    23604.500000
# max    30485.000000

# %%
#df_2['Date'] = df_2['Date'].str.split(expand=True)[0]
#df_2['Date'] = pd.to_datetime(df_2['Date'])
#df_2['year'] = df_2['Date'].dt.year
#df_2['month'] = df_2['Date'].dt.month
#mask= df_2['year'] == 1986
#filtered = df_2[mask]
#filtered.head()

# %%
df_2.plot(x = "Date", y= "Total", figsize=(15, 6))
plt.title(f'Catfish sales')
plt.xlabel('Date')
plt.ylabel("Sales")
plt.show()

# %%
df_3 = pd.read_csv('../contenido/TimeSeries/Datasets/RIGO.2012.2021.csv')
df_3.head()
# Out:
#    Unnamed: 0                fechaHora  ultimoPrecio
# 0           0  2021-06-24 17:00:12.143         150.0
# 1           1  2021-06-23 12:00:20.050         150.0
# 2           2  2021-06-22 17:00:17.973         150.0
# 3           3  2021-06-18 12:00:07.107         151.0
# 4           4  2021-06-17 17:00:15.310         148.0

# %%
df_3.tail()
# Out:
#       Unnamed: 0                fechaHora  ultimoPrecio
# 2754        2754  2010-01-08 00:00:00.000      5.424325
# 2755        2755  2010-01-07 00:00:00.000      5.367826
# 2756        2756  2010-01-06 00:00:00.000      5.226569
# 2757        2757  2010-01-05 00:00:00.000      5.226569
# 2758        2758  2010-01-04 00:00:00.000      5.085303

# %%
df_3.describe()
# Out:
#         Unnamed: 0  ultimoPrecio
# count  2759.000000   2759.000000
# mean   1379.000000     40.722776
# std     796.599021     33.524323
# min       0.000000      5.085303
# 25%     689.500000     18.423462
# 50%    1379.000000     27.983591
# 75%    2068.500000     60.000000
# max    2758.000000    154.500000

# %%
df_3.plot(x = "fechaHora", y= "ultimoPrecio", figsize=(15, 6))
plt.title(f'Rigo')
plt.xlabel('Date')
plt.ylabel("Price")
plt.show()

# %%
df_4 = pd.read_csv('./data/coffee.csv')
df_4.head()
# Out:
#          Date    Open    High     Low   Close  Volume Currency
# 0  2000-01-03  122.25  124.00  116.10  116.50    6640      USD
# 1  2000-01-04  116.25  120.50  115.75  116.25    5492      USD
# 2  2000-01-05  115.00  121.00  115.00  118.60    6165      USD
# 3  2000-01-06  119.00  121.40  116.50  116.85    5094      USD
# 4  2000-01-07  117.25  117.75  113.80  114.15    6855      USD

# %% [markdown]
# ## Opciones para tp final

# %%
df_4.plot(x = "Date", y= "Close", figsize=(15, 6))
plt.title(f'price coffee')
plt.xlabel('Date')
plt.ylabel("Close")
plt.show()

# %%
df_5 = pd.read_csv('./data/crimeDate.csv')
df_5.head()
# Out:
#          date         primary_type  crime_count  arrest_count  false_count
# 0  2001-01-01  MOTOR VEHICLE THEFT           59             9           50
# 1  2001-01-01    WEAPONS VIOLATION           32            26            6
# 2  2001-01-01   DECEPTIVE PRACTICE           78            16           62
# 3  2001-01-01    CRIMINAL TRESPASS           29            17           12
# 4  2001-01-01             GAMBLING            2             2            0

# %%
df_5.size
# Out:
# 709275

# %%
df_5.plot(x = "date", y= "false_count", figsize=(15, 6))
plt.title(f'Crime in Chicago')
plt.xlabel('Date')
plt.ylabel("false_count")
plt.show()
